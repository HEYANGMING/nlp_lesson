# %% [markdown]
# # Search problem: Beijing Subway

# %%
import requests, re, urllib.request

# %%
def get_reponse_TEXT(url):
    """
    获取url连接中的页面信息TEXT
    """
    headers = {"User-Agent": "User-Agent:Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0;"}
    reponse = requests.get(url, headers=headers, allow_redirects=False)
    reponse.encoding = reponse.apparent_encoding
    return reponse.text

# %%
def find_target(target, string):
    """
    在string中获取所有符合正则表达式target的字符的集合（有重复字符）
    """
    re_compile = re.compile(target)
    result = re_compile.findall(string)
    return result

# %%
def find_name(name, string):
    """
    在string中获取第一个符合正则表达式name的字符串
    """
    return re.search(name, string)

# %%
def find_Chinese_or_digits(word):
    """
    对爬取得到的字符进行处理，如： '>3号航站楼站</'  ->  '3号航站楼站'
    """
    return ''.join(ch for ch in word if (('\u4e00' <= ch <= '\u9fff') or ch.isdigit()))

# %%
def find_table(text):
    """
    获取网页中车站信息列表
    """
    start = -1
    if text.find('车站列表</caption>') > 0:
        start = text.find('车站列表</caption>')
    elif text.find('车站列表</h3>') > 0:
        start = text.find('车站列表</h3>')
    elif text.find('车站列表<br/>') > 0:
        start = text.find('车站列表<br/>')
    elif text.find('车站信息</caption>') > 0:
        start = text.find('车站信息</caption>')
    elif text.find('车站信息</h3>') > 0:
        start = text.find('车站信息</h3>')

    end = start + text[start:].find('</table>')
    table = text[start:end]
    
    return table

    
    #if '车站名称' in table:
     #   return table
    #else:
     #   return find_table(text[start + 1:])  ##个别网页，《车站列表》下会有几个表格，前几个表格可能是无关信息，需舍去。

# %%
def get_line(url):
    """
    获取某条线路网页中的车站信息
    """
    TEXT = get_reponse_TEXT(url)

    linename = find_name('<title>北京地铁\w*线', TEXT).group()

    table = find_table(TEXT)

    line_pri = find_target('>\d*[\u4e00-\u9fa5]+站</', table)

    line = [find_Chinese_or_digits(entry) for entry in line_pri]
    linename = find_Chinese_or_digits(linename)
    return line, linename

# %%
def get_line_station_dict(url_source, target_source):
    reponse_text = get_reponse_TEXT(url_source)

    set_url_line = set(find_target(target_source, reponse_text))
    list_url_line = ['https://baike.baidu.com' + entry for entry in set_url_line]
    
    #北京西郊线，网页无法爬取，故不作计算
    # list_url_line.remove('https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E8%A5%BF%E9%83%8A%E7%BA%BF')  
    
    dict_line = {}
    i = 0

    for line_url in list_url_line:
        print(line_url)
        temp_line, temp_linename = get_line(line_url)
        i += 1

        if len(temp_line) > 0:
            dict_line[temp_linename] = temp_line
            print('linename= {}  ,success! i= {}'.format(temp_linename, i))
        else:
            print('linename= {}  ,defeated! i= {}'.format(temp_linename, i))

    return dict_line

# %%
## 源网站url
url_source = 'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81/408485'
## 各地铁线网页url正则表达式匹配符
target_source = '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81\w*%E\d+.?\w*.?\w*.?E?\d*.?\w*.?\w*.?\w*%BA%BF'

# %%
dict_line = {}
dict_line = get_line_station_dict(url_source, target_source)
# Out:
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%816%E5%8F%B7%E7%BA%BF
# linename= 北京地铁6号线  ,success! i= 1
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%819%E5%8F%B7%E7%BA%BF
# linename= 北京地铁9号线  ,success! i= 2
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%98%8C%E5%B9%B3%E7%BA%BF
# linename= 北京地铁昌平线  ,success! i= 3
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%812%E5%8F%B7%E7%BA%BF
# linename= 北京地铁2号线  ,success! i= 4
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%811%E5%8F%B7%E7%BA%BF
# linename= 北京地铁1号线  ,success! i= 5
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E7%87%95%E6%88%BF%E7%BA%BF
# linename= 北京地铁燕房线  ,success! i= 6
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E4%BA%A6%E5%BA%84%E7%BA%BF
# linename= 北京地铁亦庄线  ,defeated! i= 7
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%88%BF%E5%B1%B1%E7%BA%BF
# linename= 北京地铁房山线  ,success! i= 8
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E5%85%AB%E9%80%9A%E7%BA%BF
# linename= 北京地铁八通线  ,success! i= 9
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8113%E5%8F%B7%E7%BA%BF
# linename= 北京地铁13号线  ,success! i= 10
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%814%E5%8F%B7%E7%BA%BF
# linename= 北京地铁4号线  ,success! i= 11
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%815%E5%8F%B7%E7%BA%BF
# linename= 北京地铁5号线  ,success! i= 12
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81S1%E7%BA%BF
# linename= 北京地铁1线  ,success! i= 13
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8110%E5%8F%B7%E7%BA%BF
# linename= 北京地铁10号线  ,success! i= 14
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%818%E5%8F%B7%E7%BA%BF
# linename= 北京地铁8号线  ,success! i= 15
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8115%E5%8F%B7%E7%BA%BF
# linename= 北京地铁15号线  ,success! i= 16
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%817%E5%8F%B7%E7%BA%BF
# linename= 北京地铁7号线  ,success! i= 17
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8114%E5%8F%B7%E7%BA%BF
# linename= 北京地铁14号线  ,success! i= 18
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%9C%BA%E5%9C%BA%E7%BA%BF
# linename= 北京地铁机场线  ,success! i= 19
# https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8116%E5%8F%B7%E7%BA%BF
# linename= 北京地铁16号线  ,success! i= 20

# %%
len(dict_line)
# Out:
# 19

# %% [markdown]
# ## Search the optimal route
#
# 根据过站数及换线次数 ，寻找最优路径

# %%
import collections

# %%
def is_goal(destation, by_way):
    """
    判断是否达到目标
    """
    
    def is_goal_(path):
        station, _, _, _ = path[-1]
        if station == destation:
            i = 0
            n = len(by_way)
            if i == n: return True
            
            path_state = path[::2]
            
            for state in path_state:
                if state[0] in by_way: i += 1
                if i == n: return True
        return False
    
    return is_goal_

# %%
def double(list_example):
    return [list_example[i:i+2] for i in range(len(list_example)-1)]

# %%
def subways(lines):   
    dict_successors = collections.defaultdict(dict)
    for linename, stations in lines.items():
         for a, b in double(stations):
            dict_successors[a][b] = linename
            dict_successors[b][a] = linename
    return dict_successors

# %%
def successors(state):
    """
    给出此状态下所有可能动作，及动作结果
    """
    station, linename, changelinetimes, changestoptimes = state
    result = []
    for stop, lname in dict_successors[station].items():
        action = ' -> '.join([linename, lname])
        if lname != linename:
            result.append((action, (stop, lname, changelinetimes+1, changestoptimes+1)))
        else:
            result.append((action, (stop, linename, changelinetimes, changestoptimes+1)))
    return result

# %%
def comparison(path):
    """
    给出路径比较规则
    """
    _, _, changelinetimes, changestoptimes = path[-1]

    return (2*changelinetimes + changestoptimes)          ##换一次线路大致等于走过两站

# %%
def Search(state_start, is_goal, successors, comparison):
    paths = [[state_start]]
    seen = []
    while paths:
        path = paths.pop(0)
        state_now = path[-1]
        if is_goal(path):
#             for i in paths:
#                 if is_goal(i):print(i)
            return path
        seen.append(state_now[0])
        for action, state in successors(state_now):
            if state[0] in seen:
                continue
            path_new = path + [action] + [state]
            paths.append(path_new)
        paths = sorted(paths, key=comparison, reverse = False)
    return False

# %%
dict_successors = subways(dict_line)

# %%
dict_successors
# Out:
# defaultdict(dict,
#             {'金安桥站': {'苹果园站': '北京地铁1线', '四道桥站': '北京地铁1线'},
#              '苹果园站': {'金安桥站': '北京地铁1线',
#               '杨庄站': '北京地铁6号线',
#               '福寿岭站': '北京地铁1号线',
#               '古城站': '北京地铁1号线'},
#              '杨庄站': {'苹果园站': '北京地铁6号线', '西黄村站': '北京地铁6号线'},
#              '西黄村站': {'杨庄站': '北京地铁6号线', '廖公庄站': '北京地铁6号线'},
#              '廖公庄站': {'西黄村站': '北京地铁6号线', '田村站': '北京地铁6号线'},
#              '田村站': {'廖公庄站': '北京地铁6号线', '海淀五路居站': '北京地铁6号线'},
#              '海淀五路居站': {'田村站': '北京地铁6号线', '慈寿寺站': '北京地铁6号线'},
#              '慈寿寺站': {'海淀五路居站': '北京地铁6号线',
#               '花园桥站': '北京地铁6号线',
#               '西钓鱼台站': '北京地铁10号线',
#               '车道沟站': '北京地铁10号线'},
#              '花园桥站': {'慈寿寺站': '北京地铁6号线', '白石桥南站': '北京地铁6号线'},
#              '白石桥南站': {'花园桥站': '北京地铁6号线',
#               '二里沟站': '北京地铁6号线',
#               '白堆子站': '北京地铁9号线',
#               '国家图书馆站': '北京地铁9号线'},
#              '二里沟站': {'白石桥南站': '北京地铁6号线',
#               '车公庄西站': '北京地铁6号线',
#               '甘家口站': '北京地铁16号线',
#               '国家图书馆站': '北京地铁16号线'},
#              '车公庄西站': {'二里沟站': '北京地铁6号线', '车公庄站': '北京地铁6号线'},
#              '车公庄站': {'车公庄西站': '北京地铁6号线',
#               '平安里站': '北京地铁6号线',
#               '阜成门站': '北京地铁2号线',
#               '西直门站': '北京地铁2号线'},
#              '平安里站': {'车公庄站': '北京地铁6号线',
#               '北海北站': '北京地铁6号线',
#               '西四站': '北京地铁4号线',
#               '新街口站': '北京地铁4号线'},
#              '北海北站': {'平安里站': '北京地铁6号线', '南锣鼓巷站': '北京地铁6号线'},
#              '南锣鼓巷站': {'北海北站': '北京地铁6号线',
#               '东四站': '北京地铁6号线',
#               '什刹海站': '北京地铁8号线',
#               '中国美术馆站': '北京地铁8号线'},
#              '东四站': {'南锣鼓巷站': '北京地铁6号线',
#               '朝阳门站': '北京地铁6号线',
#               '灯市口站': '北京地铁5号线',
#               '张自忠路站': '北京地铁5号线'},
#              '朝阳门站': {'东四站': '北京地铁6号线',
#               '东大桥站': '北京地铁6号线',
#               '东四十条站': '北京地铁2号线',
#               '建国门站': '北京地铁2号线'},
#              '东大桥站': {'朝阳门站': '北京地铁6号线', '呼家楼站': '北京地铁6号线'},
#              '呼家楼站': {'东大桥站': '北京地铁6号线',
#               '金台路站': '北京地铁6号线',
#               '团结湖站': '北京地铁10号线',
#               '金台夕照站': '北京地铁10号线'},
#              '金台路站': {'呼家楼站': '北京地铁6号线',
#               '十里堡站': '北京地铁6号线',
#               '预留车站': '北京地铁14号线',
#               '朝阳公园站': '北京地铁14号线'},
#              '十里堡站': {'金台路站': '北京地铁6号线', '青年路站': '北京地铁6号线'},
#              '青年路站': {'十里堡站': '北京地铁6号线', '褡裢坡站': '北京地铁6号线'},
#              '褡裢坡站': {'青年路站': '北京地铁6号线', '黄渠站': '北京地铁6号线'},
#              '黄渠站': {'褡裢坡站': '北京地铁6号线', '常营站': '北京地铁6号线'},
#              '常营站': {'黄渠站': '北京地铁6号线', '草房站': '北京地铁6号线'},
#              '草房站': {'常营站': '北京地铁6号线', '物资学院路站': '北京地铁6号线'},
#              '物资学院路站': {'草房站': '北京地铁6号线', '通州北关站': '北京地铁6号线'},
#              '通州北关站': {'物资学院路站': '北京地铁6号线', '通运门站': '北京地铁6号线'},
#              '通运门站': {'通州北关站': '北京地铁6号线', '北运河西站': '北京地铁6号线'},
#              '北运河西站': {'通运门站': '北京地铁6号线', '北运河东站': '北京地铁6号线'},
#              '北运河东站': {'北运河西站': '北京地铁6号线', '郝家府站': '北京地铁6号线'},
#              '郝家府站': {'北运河东站': '北京地铁6号线', '东夏园站': '北京地铁6号线'},
#              '东夏园站': {'郝家府站': '北京地铁6号线', '潞城站': '北京地铁6号线'},
#              '潞城站': {'东夏园站': '北京地铁6号线'},
#              '郭公庄站': {'丰台科技园站': '北京地铁9号线',
#               '起止站': '北京地铁房山线',
#               '阎村东站': '北京地铁房山线'},
#              '丰台科技园站': {'郭公庄站': '北京地铁9号线', '科怡路站': '北京地铁9号线'},
#              '科怡路站': {'丰台科技园站': '北京地铁9号线', '丰台南路站': '北京地铁9号线'},
#              '丰台南路站': {'科怡路站': '北京地铁9号线',
#               '丰台东大街站': '北京地铁9号线',
#               '富丰桥站': '北京地铁16号线',
#               '丰台站': '北京地铁16号线'},
#              '丰台东大街站': {'丰台南路站': '北京地铁9号线', '七里庄站': '北京地铁9号线'},
#              '七里庄站': {'丰台东大街站': '北京地铁9号线',
#               '六里桥站': '北京地铁9号线',
#               '大井站': '北京地铁14号线',
#               '西局站': '北京地铁14号线'},
#              '六里桥站': {'七里庄站': '北京地铁9号线',
#               '六里桥东站': '北京地铁9号线',
#               '西局站': '北京地铁10号线',
#               '莲花桥站': '北京地铁10号线'},
#              '六里桥东站': {'六里桥站': '北京地铁9号线', '北京西站': '北京地铁9号线'},
#              '北京西站': {'六里桥东站': '北京地铁9号线',
#               '军事博物馆站': '北京地铁9号线',
#               '湾子站': '北京地铁7号线'},
#              '军事博物馆站': {'北京西站': '北京地铁9号线',
#               '白堆子站': '北京地铁9号线',
#               '公主坟站': '北京地铁1号线',
#               '木樨地站': '北京地铁1号线'},
#              '白堆子站': {'军事博物馆站': '北京地铁9号线', '白石桥南站': '北京地铁9号线'},
#              '国家图书馆站': {'白石桥南站': '北京地铁9号线',
#               '动物园站': '北京地铁4号线',
#               '魏公村站': '北京地铁4号线',
#               '二里沟站': '北京地铁16号线',
#               '万寿寺站': '北京地铁16号线'},
#              '西二旗站': {'生命科学园站': '北京地铁昌平线',
#               '清河站': '北京地铁13号线',
#               '龙泽站': '北京地铁13号线'},
#              '生命科学园站': {'西二旗站': '北京地铁昌平线', '朱辛庄站': '北京地铁昌平线'},
#              '朱辛庄站': {'生命科学园站': '北京地铁昌平线',
#               '巩华城站': '北京地铁昌平线',
#               '育知路站': '北京地铁8号线'},
#              '巩华城站': {'朱辛庄站': '北京地铁昌平线', '沙河站': '北京地铁昌平线'},
#              '沙河站': {'巩华城站': '北京地铁昌平线', '沙河高教园站': '北京地铁昌平线'},
#              '沙河高教园站': {'沙河站': '北京地铁昌平线', '南邵站': '北京地铁昌平线'},
#              '南邵站': {'沙河高教园站': '北京地铁昌平线', '北邵洼站': '北京地铁昌平线'},
#              '北邵洼站': {'南邵站': '北京地铁昌平线', '昌平东关站': '北京地铁昌平线'},
#              '昌平东关站': {'北邵洼站': '北京地铁昌平线', '昌平站': '北京地铁昌平线'},
#              '昌平站': {'昌平东关站': '北京地铁昌平线', '昌平北站': '北京地铁昌平线'},
#              '昌平北站': {'昌平站': '北京地铁昌平线', '十三陵景区站': '北京地铁昌平线'},
#              '十三陵景区站': {'昌平北站': '北京地铁昌平线', '昌平西山口站': '北京地铁昌平线'},
#              '昌平西山口站': {'十三陵景区站': '北京地铁昌平线'},
#              '西直门站': {'积水潭站': '北京地铁2号线',
#               '车公庄站': '北京地铁2号线',
#               '北京北站': '北京地铁13号线',
#               '新街口站': '北京地铁4号线',
#               '动物园站': '北京地铁4号线'},
#              '积水潭站': {'西直门站': '北京地铁2号线', '鼓楼大街站': '北京地铁2号线'},
#              '鼓楼大街站': {'积水潭站': '北京地铁2号线',
#               '安定门站': '北京地铁2号线',
#               '安德里北街站': '北京地铁8号线',
#               '什刹海站': '北京地铁8号线'},
#              '安定门站': {'鼓楼大街站': '北京地铁2号线', '雍和宫站': '北京地铁2号线'},
#              '雍和宫站': {'安定门站': '北京地铁2号线',
#               '东直门站': '北京地铁2号线',
#               '北新桥站': '北京地铁5号线',
#               '和平里北街站': '北京地铁5号线'},
#              '东直门站': {'雍和宫站': '北京地铁2号线',
#               '东四十条站': '北京地铁2号线',
#               '柳芳站': '北京地铁13号线',
#               '三元桥站': '北京地铁机场线'},
#              '东四十条站': {'东直门站': '北京地铁2号线', '朝阳门站': '北京地铁2号线'},
#              '建国门站': {'朝阳门站': '北京地铁2号线',
#               '北京站': '北京地铁2号线',
#               '东单站': '北京地铁1号线',
#               '永安里站': '北京地铁1号线'},
#              '北京站': {'建国门站': '北京地铁2号线', '崇文门站': '北京地铁2号线'},
#              '崇文门站': {'北京站': '北京地铁2号线',
#               '前门站': '北京地铁2号线',
#               '磁器口站': '北京地铁5号线',
#               '东单站': '北京地铁5号线'},
#              '前门站': {'崇文门站': '北京地铁2号线',
#               '和平门站': '北京地铁2号线',
#               '王府井站': '北京地铁8号线',
#               '珠市口站': '北京地铁8号线'},
#              '和平门站': {'前门站': '北京地铁2号线', '宣武门站': '北京地铁2号线'},
#              '宣武门站': {'和平门站': '北京地铁2号线',
#               '长椿街站': '北京地铁2号线',
#               '菜市口站': '北京地铁4号线',
#               '西单站': '北京地铁4号线'},
#              '长椿街站': {'宣武门站': '北京地铁2号线', '复兴门站': '北京地铁2号线'},
#              '复兴门站': {'长椿街站': '北京地铁2号线',
#               '阜成门站': '北京地铁2号线',
#               '南礼士路站': '北京地铁1号线',
#               '西单站': '北京地铁1号线'},
#              '阜成门站': {'复兴门站': '北京地铁2号线', '车公庄站': '北京地铁2号线'},
#              '黑石头站': {'高井站': '北京地铁1号线'},
#              '高井站': {'黑石头站': '北京地铁1号线', '福寿岭站': '北京地铁1号线'},
#              '福寿岭站': {'高井站': '北京地铁1号线', '苹果园站': '北京地铁1号线'},
#              '古城站': {'苹果园站': '北京地铁1号线', '衙门口站': '北京地铁1号线'},
#              '衙门口站': {'古城站': '北京地铁1号线', '八角游乐园站': '北京地铁1号线'},
#              '八角游乐园站': {'衙门口站': '北京地铁1号线', '八宝山站': '北京地铁1号线'},
#              '八宝山站': {'八角游乐园站': '北京地铁1号线', '玉泉路站': '北京地铁1号线'},
#              '玉泉路站': {'八宝山站': '北京地铁1号线', '五棵松站': '北京地铁1号线'},
#              '五棵松站': {'玉泉路站': '北京地铁1号线', '万寿路站': '北京地铁1号线'},
#              '万寿路站': {'五棵松站': '北京地铁1号线', '公主坟站': '北京地铁1号线'},
#              '公主坟站': {'万寿路站': '北京地铁1号线',
#               '军事博物馆站': '北京地铁1号线',
#               '莲花桥站': '北京地铁10号线',
#               '西钓鱼台站': '北京地铁10号线'},
#              '木樨地站': {'军事博物馆站': '北京地铁1号线',
#               '南礼士路站': '北京地铁1号线',
#               '达官营站': '北京地铁16号线',
#               '玉渊潭站': '北京地铁16号线'},
#              '南礼士路站': {'木樨地站': '北京地铁1号线', '复兴门站': '北京地铁1号线'},
#              '西单站': {'复兴门站': '北京地铁1号线',
#               '天安门西站': '北京地铁1号线',
#               '宣武门站': '北京地铁4号线',
#               '灵境胡同站': '北京地铁4号线'},
#              '天安门西站': {'西单站': '北京地铁1号线', '天安门东站': '北京地铁1号线'},
#              '天安门东站': {'天安门西站': '北京地铁1号线', '王府井站': '北京地铁1号线'},
#              '王府井站': {'天安门东站': '北京地铁1号线',
#               '东单站': '北京地铁1号线',
#               '金鱼胡同站': '北京地铁8号线',
#               '前门站': '北京地铁8号线'},
#              '东单站': {'王府井站': '北京地铁1号线',
#               '建国门站': '北京地铁1号线',
#               '崇文门站': '北京地铁5号线',
#               '灯市口站': '北京地铁5号线'},
#              '永安里站': {'建国门站': '北京地铁1号线', '国贸站': '北京地铁1号线'},
#              '国贸站': {'永安里站': '北京地铁1号线',
#               '大望路站': '北京地铁1号线',
#               '金台夕照站': '北京地铁10号线',
#               '双井站': '北京地铁10号线'},
#              '大望路站': {'国贸站': '北京地铁1号线',
#               '四惠站': '北京地铁1号线',
#               '九龙山站': '北京地铁14号线',
#               '红庙站': '北京地铁14号线'},
#              '四惠站': {'大望路站': '北京地铁1号线', '四惠东站': '北京地铁八通线'},
#              '四惠东站': {'四惠站': '北京地铁八通线', '高碑店站': '北京地铁八通线'},
#              '高碑店站': {'四惠东站': '北京地铁八通线', '传媒大学站': '北京地铁八通线'},
#              '传媒大学站': {'高碑店站': '北京地铁八通线', '双桥站': '北京地铁八通线'},
#              '双桥站': {'传媒大学站': '北京地铁八通线', '管庄站': '北京地铁八通线'},
#              '管庄站': {'双桥站': '北京地铁八通线', '八里桥站': '北京地铁八通线'},
#              '八里桥站': {'管庄站': '北京地铁八通线', '通州北苑站': '北京地铁八通线'},
#              '通州北苑站': {'八里桥站': '北京地铁八通线', '果园站': '北京地铁八通线'},
#              '果园站': {'通州北苑站': '北京地铁八通线', '九棵树站': '北京地铁八通线'},
#              '九棵树站': {'果园站': '北京地铁八通线', '梨园站': '北京地铁八通线'},
#              '梨园站': {'九棵树站': '北京地铁八通线', '临河里站': '北京地铁八通线'},
#              '临河里站': {'梨园站': '北京地铁八通线', '土桥站': '北京地铁八通线'},
#              '土桥站': {'临河里站': '北京地铁八通线', '花庄站': '北京地铁1号线', '施园站': '北京地铁八通线'},
#              '花庄站': {'土桥站': '北京地铁1号线', '环球度假区站': '北京地铁1号线'},
#              '环球度假区站': {'花庄站': '北京地铁1号线'},
#              '阎村东站': {'紫草坞站': '北京地铁燕房线', '郭公庄站': '北京地铁房山线'},
#              '紫草坞站': {'阎村东站': '北京地铁燕房线', '阎村站': '北京地铁燕房线'},
#              '阎村站': {'紫草坞站': '北京地铁燕房线', '星城站': '北京地铁燕房线'},
#              '星城站': {'阎村站': '北京地铁燕房线', '大石河东站': '北京地铁燕房线'},
#              '大石河东站': {'星城站': '北京地铁燕房线', '马各庄站': '北京地铁燕房线'},
#              '马各庄站': {'大石河东站': '北京地铁燕房线', '饶乐府站': '北京地铁燕房线'},
#              '饶乐府站': {'马各庄站': '北京地铁燕房线', '房山城关站': '北京地铁燕房线'},
#              '房山城关站': {'饶乐府站': '北京地铁燕房线', '燕山站': '北京地铁燕房线'},
#              '燕山站': {'房山城关站': '北京地铁燕房线', '老城区站': '北京地铁燕房线'},
#              '老城区站': {'燕山站': '北京地铁燕房线', '顾册站': '北京地铁燕房线'},
#              '顾册站': {'老城区站': '北京地铁燕房线', '周口店镇站': '北京地铁燕房线'},
#              '周口店镇站': {'顾册站': '北京地铁燕房线'},
#              '起止站': {'郭公庄站': '北京地铁房山线'},
#              '施园站': {'土桥站': '北京地铁八通线', '环球影城站': '北京地铁7号线', '高楼金站': '北京地铁7号线'},
#              '环球影城站': {'施园站': '北京地铁7号线'},
#              '北京北站': {'西直门站': '北京地铁13号线', '大钟寺站': '北京地铁13号线'},
#              '大钟寺站': {'北京北站': '北京地铁13号线', '知春路站': '北京地铁13号线'},
#              '知春路站': {'大钟寺站': '北京地铁13号线',
#               '五道口站': '北京地铁13号线',
#               '知春里站': '北京地铁10号线',
#               '西土城站': '北京地铁10号线'},
#              '五道口站': {'知春路站': '北京地铁13号线', '上地站': '北京地铁13号线'},
#              '上地站': {'五道口站': '北京地铁13号线', '清河站': '北京地铁13号线'},
#              '清河站': {'上地站': '北京地铁13号线', '西二旗站': '北京地铁13号线'},
#              '龙泽站': {'西二旗站': '北京地铁13号线', '回龙观站': '北京地铁13号线'},
#              '回龙观站': {'龙泽站': '北京地铁13号线', '霍营站': '北京地铁13号线'},
#              '霍营站': {'回龙观站': '北京地铁13号线',
#               '立水桥站': '北京地铁13号线',
#               '回龙观东大街站': '北京地铁8号线',
#               '育新站': '北京地铁8号线'},
#              '立水桥站': {'霍营站': '北京地铁13号线',
#               '北苑站': '北京地铁13号线',
#               '立水桥南站': '北京地铁5号线',
#               '天通苑南站': '北京地铁5号线'},
#              '北苑站': {'立水桥站': '北京地铁13号线', '望京西站': '北京地铁13号线'},
#              '望京西站': {'北苑站': '北京地铁13号线',
#               '芍药居站': '北京地铁13号线',
#               '关庄站': '北京地铁15号线',
#               '望京站': '北京地铁15号线'},
#              '芍药居站': {'望京西站': '北京地铁13号线',
#               '光熙门站': '北京地铁13号线',
#               '惠新西街南口站': '北京地铁10号线',
#               '太阳宫站': '北京地铁10号线'},
#              '光熙门站': {'芍药居站': '北京地铁13号线', '柳芳站': '北京地铁13号线'},
#              '柳芳站': {'光熙门站': '北京地铁13号线', '东直门站': '北京地铁13号线'},
#              '公益西桥站': {'角门西站': '北京地铁4号线'},
#              '角门西站': {'公益西桥站': '北京地铁4号线',
#               '马家堡站': '北京地铁4号线',
#               '角门东站': '北京地铁10号线',
#               '草桥站': '北京地铁10号线'},
#              '马家堡站': {'角门西站': '北京地铁4号线', '北京南站': '北京地铁4号线'},
#              '北京南站': {'马家堡站': '北京地铁4号线',
#               '陶然亭站': '北京地铁4号线',
#               '景风门站': '北京地铁14号线',
#               '陶然桥站': '北京地铁14号线'},
#              '陶然亭站': {'北京南站': '北京地铁4号线', '菜市口站': '北京地铁4号线'},
#              '菜市口站': {'陶然亭站': '北京地铁4号线',
#               '宣武门站': '北京地铁4号线',
#               '广安门内站': '北京地铁7号线',
#               '虎坊桥站': '北京地铁7号线'},
#              '灵境胡同站': {'西单站': '北京地铁4号线', '西四站': '北京地铁4号线'},
#              '西四站': {'灵境胡同站': '北京地铁4号线', '平安里站': '北京地铁4号线'},
#              '新街口站': {'平安里站': '北京地铁4号线', '西直门站': '北京地铁4号线'},
#              '动物园站': {'西直门站': '北京地铁4号线', '国家图书馆站': '北京地铁4号线'},
#              '魏公村站': {'国家图书馆站': '北京地铁4号线', '人民大学站': '北京地铁4号线'},
#              '人民大学站': {'魏公村站': '北京地铁4号线', '海淀黄庄站': '北京地铁4号线'},
#              '海淀黄庄站': {'人民大学站': '北京地铁4号线',
#               '中关村站': '北京地铁4号线',
#               '苏州街站': '北京地铁10号线',
#               '知春里站': '北京地铁10号线'},
#              '中关村站': {'海淀黄庄站': '北京地铁4号线', '北京大学东门站': '北京地铁4号线'},
#              '北京大学东门站': {'中关村站': '北京地铁4号线', '圆明园站': '北京地铁4号线'},
#              '圆明园站': {'北京大学东门站': '北京地铁4号线', '西苑站': '北京地铁4号线'},
#              '西苑站': {'圆明园站': '北京地铁4号线',
#               '北宫门站': '北京地铁4号线',
#               '万泉河桥站': '北京地铁16号线',
#               '农大南路站': '北京地铁16号线'},
#              '北宫门站': {'西苑站': '北京地铁4号线', '安河桥北站': '北京地铁4号线'},
#              '安河桥北站': {'北宫门站': '北京地铁4号线'},
#              '宋家庄站': {'刘家窑站': '北京地铁5号线',
#               '成寿寺站': '北京地铁10号线',
#               '石榴庄站': '北京地铁10号线'},
#              '刘家窑站': {'宋家庄站': '北京地铁5号线', '蒲黄榆站': '北京地铁5号线'},
#              '蒲黄榆站': {'刘家窑站': '北京地铁5号线',
#               '天坛东门站': '北京地铁5号线',
#               '景泰站': '北京地铁14号线',
#               '方庄站': '北京地铁14号线'},
#              '天坛东门站': {'蒲黄榆站': '北京地铁5号线', '磁器口站': '北京地铁5号线'},
#              '磁器口站': {'天坛东门站': '北京地铁5号线',
#               '崇文门站': '北京地铁5号线',
#               '桥湾站': '北京地铁7号线',
#               '广渠门内站': '北京地铁7号线'},
#              '灯市口站': {'东单站': '北京地铁5号线', '东四站': '北京地铁5号线'},
#              '张自忠路站': {'东四站': '北京地铁5号线', '北新桥站': '北京地铁5号线'},
#              '北新桥站': {'张自忠路站': '北京地铁5号线', '雍和宫站': '北京地铁5号线'},
#              '和平里北街站': {'雍和宫站': '北京地铁5号线', '和平西桥站': '北京地铁5号线'},
#              '和平西桥站': {'和平里北街站': '北京地铁5号线', '惠新西街南口站': '北京地铁5号线'},
#              '惠新西街南口站': {'和平西桥站': '北京地铁5号线',
#               '惠新西街北口站': '北京地铁5号线',
#               '安贞门站': '北京地铁10号线',
#               '芍药居站': '北京地铁10号线'},
#              '惠新西街北口站': {'惠新西街南口站': '北京地铁5号线', '大屯路东站': '北京地铁5号线'},
#              '大屯路东站': {'惠新西街北口站': '北京地铁5号线',
#               '北苑路北站': '北京地铁5号线',
#               '安立路站': '北京地铁15号线',
#               '关庄站': '北京地铁15号线'},
#              '北苑路北站': {'大屯路东站': '北京地铁5号线', '立水桥南站': '北京地铁5号线'},
#              '立水桥南站': {'北苑路北站': '北京地铁5号线', '立水桥站': '北京地铁5号线'},
#              '天通苑南站': {'立水桥站': '北京地铁5号线', '天通苑站': '北京地铁5号线'},
#              '天通苑站': {'天通苑南站': '北京地铁5号线', '天通苑北站': '北京地铁5号线'},
#              '天通苑北站': {'天通苑站': '北京地铁5号线'},
#              '四道桥站': {'金安桥站': '北京地铁1线', '桥户营站': '北京地铁1线'},
#              '桥户营站': {'四道桥站': '北京地铁1线', '上岸站': '北京地铁1线'},
#              '上岸站': {'桥户营站': '北京地铁1线', '栗园庄站': '北京地铁1线'},
#              '栗园庄站': {'上岸站': '北京地铁1线', '小园站': '北京地铁1线'},
#              '小园站': {'栗园庄站': '北京地铁1线', '石厂站': '北京地铁1线'},
#              '石厂站': {'小园站': '北京地铁1线'},
#              '巴沟站': {'苏州街站': '北京地铁10号线', '火器营站': '北京地铁10号线'},
#              '苏州街站': {'巴沟站': '北京地铁10号线',
#               '海淀黄庄站': '北京地铁10号线',
#               '苏州桥站': '北京地铁16号线',
#               '万泉河桥站': '北京地铁16号线'},
#              '知春里站': {'海淀黄庄站': '北京地铁10号线', '知春路站': '北京地铁10号线'},
#              '西土城站': {'知春路站': '北京地铁10号线', '牡丹园站': '北京地铁10号线'},
#              '牡丹园站': {'西土城站': '北京地铁10号线', '健德门站': '北京地铁10号线'},
#              '健德门站': {'牡丹园站': '北京地铁10号线', '北土城站': '北京地铁10号线'},
#              '北土城站': {'健德门站': '北京地铁10号线',
#               '安贞门站': '北京地铁10号线',
#               '奥体中心站': '北京地铁8号线',
#               '安华桥站': '北京地铁8号线'},
#              '安贞门站': {'北土城站': '北京地铁10号线', '惠新西街南口站': '北京地铁10号线'},
#              '太阳宫站': {'芍药居站': '北京地铁10号线', '三元桥站': '北京地铁10号线'},
#              '三元桥站': {'太阳宫站': '北京地铁10号线',
#               '亮马桥站': '北京地铁10号线',
#               '东直门站': '北京地铁机场线',
#               '3号航站楼站': '北京地铁机场线'},
#              '亮马桥站': {'三元桥站': '北京地铁10号线', '农业展览馆站': '北京地铁10号线'},
#              '农业展览馆站': {'亮马桥站': '北京地铁10号线', '团结湖站': '北京地铁10号线'},
#              '团结湖站': {'农业展览馆站': '北京地铁10号线', '呼家楼站': '北京地铁10号线'},
#              '金台夕照站': {'呼家楼站': '北京地铁10号线', '国贸站': '北京地铁10号线'},
#              '双井站': {'国贸站': '北京地铁10号线',
#               '劲松站': '北京地铁10号线',
#               '广渠门外站': '北京地铁7号线',
#               '九龙山站': '北京地铁7号线'},
#              '劲松站': {'双井站': '北京地铁10号线', '潘家园站': '北京地铁10号线'},
#              '潘家园站': {'劲松站': '北京地铁10号线', '十里河站': '北京地铁10号线'},
#              '十里河站': {'潘家园站': '北京地铁10号线',
#               '分钟寺站': '北京地铁10号线',
#               '方庄站': '北京地铁14号线',
#               '北工大西门站': '北京地铁14号线'},
#              '分钟寺站': {'十里河站': '北京地铁10号线', '成寿寺站': '北京地铁10号线'},
#              '成寿寺站': {'分钟寺站': '北京地铁10号线', '宋家庄站': '北京地铁10号线'},
#              '石榴庄站': {'宋家庄站': '北京地铁10号线', '大红门站': '北京地铁10号线'},
#              '大红门站': {'石榴庄站': '北京地铁10号线',
#               '角门东站': '北京地铁10号线',
#               '海户屯站': '北京地铁8号线',
#               '大红门南站': '北京地铁8号线'},
#              '角门东站': {'大红门站': '北京地铁10号线', '角门西站': '北京地铁10号线'},
#              '草桥站': {'角门西站': '北京地铁10号线', '纪家庙站': '北京地铁10号线'},
#              '纪家庙站': {'草桥站': '北京地铁10号线', '首经贸站': '北京地铁10号线'},
#              '首经贸站': {'纪家庙站': '北京地铁10号线', '丰台站': '北京地铁10号线'},
#              '丰台站': {'首经贸站': '北京地铁10号线',
#               '泥洼站': '北京地铁10号线',
#               '丰台南路站': '北京地铁16号线',
#               '丰益桥南站': '北京地铁16号线'},
#              '泥洼站': {'丰台站': '北京地铁10号线', '西局站': '北京地铁10号线'},
#              '西局站': {'泥洼站': '北京地铁10号线',
#               '六里桥站': '北京地铁10号线',
#               '七里庄站': '北京地铁14号线',
#               '东管头站': '北京地铁14号线'},
#              '莲花桥站': {'六里桥站': '北京地铁10号线', '公主坟站': '北京地铁10号线'},
#              '西钓鱼台站': {'公主坟站': '北京地铁10号线', '慈寿寺站': '北京地铁10号线'},
#              '车道沟站': {'慈寿寺站': '北京地铁10号线', '长春桥站': '北京地铁10号线'},
#              '长春桥站': {'车道沟站': '北京地铁10号线', '火器营站': '北京地铁10号线'},
#              '火器营站': {'长春桥站': '北京地铁10号线', '巴沟站': '北京地铁10号线'},
#              '育知路站': {'朱辛庄站': '北京地铁8号线', '平西府站': '北京地铁8号线'},
#              '平西府站': {'育知路站': '北京地铁8号线', '回龙观东大街站': '北京地铁8号线'},
#              '回龙观东大街站': {'平西府站': '北京地铁8号线', '霍营站': '北京地铁8号线'},
#              '育新站': {'霍营站': '北京地铁8号线', '西小口站': '北京地铁8号线'},
#              '西小口站': {'育新站': '北京地铁8号线', '永泰庄站': '北京地铁8号线'},
#              '永泰庄站': {'西小口站': '北京地铁8号线', '林萃桥站': '北京地铁8号线'},
#              '林萃桥站': {'永泰庄站': '北京地铁8号线', '森林公园南门站': '北京地铁8号线'},
#              '森林公园南门站': {'林萃桥站': '北京地铁8号线', '奥林匹克公园站': '北京地铁8号线'},
#              '奥林匹克公园站': {'森林公园南门站': '北京地铁8号线',
#               '奥体中心站': '北京地铁8号线',
#               '北沙滩站': '北京地铁15号线',
#               '安立路站': '北京地铁15号线'},
#              '奥体中心站': {'奥林匹克公园站': '北京地铁8号线', '北土城站': '北京地铁8号线'},
#              '安华桥站': {'北土城站': '北京地铁8号线', '安德里北街站': '北京地铁8号线'},
#              '安德里北街站': {'安华桥站': '北京地铁8号线', '鼓楼大街站': '北京地铁8号线'},
#              '什刹海站': {'鼓楼大街站': '北京地铁8号线', '南锣鼓巷站': '北京地铁8号线'},
#              '中国美术馆站': {'南锣鼓巷站': '北京地铁8号线', '金鱼胡同站': '北京地铁8号线'},
#              '金鱼胡同站': {'中国美术馆站': '北京地铁8号线', '王府井站': '北京地铁8号线'},
#              '珠市口站': {'前门站': '北京地铁8号线',
#               '天桥站': '北京地铁8号线',
#               '虎坊桥站': '北京地铁7号线',
#               '桥湾站': '北京地铁7号线'},
#              '天桥站': {'珠市口站': '北京地铁8号线', '永定门外站': '北京地铁8号线'},
#              '永定门外站': {'天桥站': '北京地铁8号线',
#               '木樨园站': '北京地铁8号线',
#               '陶然桥站': '北京地铁14号线',
#               '景泰站': '北京地铁14号线'},
#              '木樨园站': {'永定门外站': '北京地铁8号线', '海户屯站': '北京地铁8号线'},
#              '海户屯站': {'木樨园站': '北京地铁8号线', '大红门站': '北京地铁8号线'},
#              '大红门南站': {'大红门站': '北京地铁8号线', '和义站': '北京地铁8号线'},
#              '和义站': {'大红门南站': '北京地铁8号线', '东高地站': '北京地铁8号线'},
#              '东高地站': {'和义站': '北京地铁8号线', '火箭万源站': '北京地铁8号线'},
#              '火箭万源站': {'东高地站': '北京地铁8号线', '五福堂站': '北京地铁8号线'},
#              '五福堂站': {'火箭万源站': '北京地铁8号线', '德茂站': '北京地铁8号线'},
#              '德茂站': {'五福堂站': '北京地铁8号线', '瀛海站': '北京地铁8号线'},
#              '瀛海站': {'德茂站': '北京地铁8号线', '瀛海南站': '北京地铁8号线'},
#              '瀛海南站': {'瀛海站': '北京地铁8号线'},
#              '清华东路西口站': {'六道口站': '北京地铁15号线'},
#              '六道口站': {'清华东路西口站': '北京地铁15号线', '北沙滩站': '北京地铁15号线'},
#              '北沙滩站': {'六道口站': '北京地铁15号线', '奥林匹克公园站': '北京地铁15号线'},
#              '安立路站': {'奥林匹克公园站': '北京地铁15号线', '大屯路东站': '北京地铁15号线'},
#              '关庄站': {'大屯路东站': '北京地铁15号线', '望京西站': '北京地铁15号线'},
#              '望京站': {'望京西站': '北京地铁15号线',
#               '望京东站': '北京地铁15号线',
#               '阜通站': '北京地铁14号线',
#               '东湖渠站': '北京地铁14号线'},
#              '望京东站': {'望京站': '北京地铁15号线', '崔各庄站': '北京地铁15号线'},
#              '崔各庄站': {'望京东站': '北京地铁15号线', '马泉营站': '北京地铁15号线'},
#              '马泉营站': {'崔各庄站': '北京地铁15号线', '孙河站': '北京地铁15号线'},
#              '孙河站': {'马泉营站': '北京地铁15号线', '国展站': '北京地铁15号线'},
#              '国展站': {'孙河站': '北京地铁15号线', '花梨坎站': '北京地铁15号线'},
#              '花梨坎站': {'国展站': '北京地铁15号线', '后沙峪站': '北京地铁15号线'},
#              '后沙峪站': {'花梨坎站': '北京地铁15号线', '南法信站': '北京地铁15号线'},
#              '南法信站': {'后沙峪站': '北京地铁15号线', '石门站': '北京地铁15号线'},
#              '石门站': {'南法信站': '北京地铁15号线', '顺义站': '北京地铁15号线'},
#              '顺义站': {'石门站': '北京地铁15号线', '俸伯站': '北京地铁15号线'},
#              '俸伯站': {'顺义站': '北京地铁15号线'},
#              '湾子站': {'北京西站': '北京地铁7号线', '达官营站': '北京地铁7号线'},
#              '达官营站': {'湾子站': '北京地铁7号线',
#               '广安门内站': '北京地铁7号线',
#               '红莲南路站': '北京地铁16号线',
#               '木樨地站': '北京地铁16号线'},
#              '广安门内站': {'达官营站': '北京地铁7号线', '菜市口站': '北京地铁7号线'},
#              '虎坊桥站': {'菜市口站': '北京地铁7号线', '珠市口站': '北京地铁7号线'},
#              '桥湾站': {'珠市口站': '北京地铁7号线', '磁器口站': '北京地铁7号线'},
#              '广渠门内站': {'磁器口站': '北京地铁7号线', '广渠门外站': '北京地铁7号线'},
#              '广渠门外站': {'广渠门内站': '北京地铁7号线', '双井站': '北京地铁7号线'},
#              '九龙山站': {'双井站': '北京地铁7号线',
#               '大郊亭站': '北京地铁7号线',
#               '平乐园站': '北京地铁14号线',
#               '大望路站': '北京地铁14号线'},
#              '大郊亭站': {'九龙山站': '北京地铁7号线', '百子湾站': '北京地铁7号线'},
#              '百子湾站': {'大郊亭站': '北京地铁7号线', '化工站': '北京地铁7号线'},
#              '化工站': {'百子湾站': '北京地铁7号线', '南楼梓庄站': '北京地铁7号线'},
#              '南楼梓庄站': {'化工站': '北京地铁7号线', '欢乐谷景区站': '北京地铁7号线'},
#              '欢乐谷景区站': {'南楼梓庄站': '北京地铁7号线', '垡头站': '北京地铁7号线'},
#              '垡头站': {'欢乐谷景区站': '北京地铁7号线', '双合站': '北京地铁7号线'},
#              '双合站': {'垡头站': '北京地铁7号线', '焦化厂站': '北京地铁7号线'},
#              '焦化厂站': {'双合站': '北京地铁7号线', '黄厂村站': '北京地铁7号线'},
#              '黄厂村站': {'焦化厂站': '北京地铁7号线', '豆各庄站': '北京地铁7号线'},
#              '豆各庄站': {'黄厂村站': '北京地铁7号线', '黑庄户站': '北京地铁7号线'},
#              '黑庄户站': {'豆各庄站': '北京地铁7号线', '万盛南街西口站': '北京地铁7号线'},
#              '万盛南街西口站': {'黑庄户站': '北京地铁7号线', '云景东路站': '北京地铁7号线'},
#              '云景东路站': {'万盛南街西口站': '北京地铁7号线', '小马庄站': '北京地铁7号线'},
#              '小马庄站': {'云景东路站': '北京地铁7号线', '高楼金站': '北京地铁7号线'},
#              '高楼金站': {'小马庄站': '北京地铁7号线', '施园站': '北京地铁7号线'},
#              '园博园站': {'大瓦窑站': '北京地铁14号线'},
#              '大瓦窑站': {'园博园站': '北京地铁14号线', '郭庄子站': '北京地铁14号线'},
#              '郭庄子站': {'大瓦窑站': '北京地铁14号线', '大井站': '北京地铁14号线'},
#              '大井站': {'郭庄子站': '北京地铁14号线', '七里庄站': '北京地铁14号线'},
#              '东管头站': {'西局站': '北京地铁14号线', '丽泽商务区站': '北京地铁14号线'},
#              '丽泽商务区站': {'东管头站': '北京地铁14号线',
#               '菜户营站': '北京地铁14号线',
#               '丰益桥南站': '北京地铁16号线',
#               '红莲南路站': '北京地铁16号线'},
#              '菜户营站': {'丽泽商务区站': '北京地铁14号线', '西铁营站': '北京地铁14号线'},
#              '西铁营站': {'菜户营站': '北京地铁14号线', '景风门站': '北京地铁14号线'},
#              '景风门站': {'西铁营站': '北京地铁14号线', '北京南站': '北京地铁14号线'},
#              '陶然桥站': {'北京南站': '北京地铁14号线', '永定门外站': '北京地铁14号线'},
#              '景泰站': {'永定门外站': '北京地铁14号线', '蒲黄榆站': '北京地铁14号线'},
#              '方庄站': {'蒲黄榆站': '北京地铁14号线', '十里河站': '北京地铁14号线'},
#              '北工大西门站': {'十里河站': '北京地铁14号线', '平乐园站': '北京地铁14号线'},
#              '平乐园站': {'北工大西门站': '北京地铁14号线', '九龙山站': '北京地铁14号线'},
#              '红庙站': {'大望路站': '北京地铁14号线', '预留车站': '北京地铁14号线'},
#              '预留车站': {'红庙站': '北京地铁14号线', '金台路站': '北京地铁14号线'},
#              '朝阳公园站': {'金台路站': '北京地铁14号线', '枣营站': '北京地铁14号线'},
#              '枣营站': {'朝阳公园站': '北京地铁14号线', '东风北桥站': '北京地铁14号线'},
#              '东风北桥站': {'枣营站': '北京地铁14号线', '将台站': '北京地铁14号线'},
#              '将台站': {'东风北桥站': '北京地铁14号线', '高家园站': '北京地铁14号线'},
#              '高家园站': {'将台站': '北京地铁14号线', '望京南站': '北京地铁14号线'},
#              '望京南站': {'高家园站': '北京地铁14号线', '阜通站': '北京地铁14号线'},
#              '阜通站': {'望京南站': '北京地铁14号线', '望京站': '北京地铁14号线'},
#              '东湖渠站': {'望京站': '北京地铁14号线', '来广营站': '北京地铁14号线'},
#              '来广营站': {'东湖渠站': '北京地铁14号线', '善各庄站': '北京地铁14号线'},
#              '善各庄站': {'来广营站': '北京地铁14号线'},
#              '3号航站楼站': {'三元桥站': '北京地铁机场线', '2号航站楼站': '北京地铁机场线'},
#              '2号航站楼站': {'3号航站楼站': '北京地铁机场线'},
#              '宛平站': {'榆树庄站': '北京地铁16号线'},
#              '榆树庄站': {'宛平站': '北京地铁16号线', '看丹站': '北京地铁16号线'},
#              '看丹站': {'榆树庄站': '北京地铁16号线', '富丰桥站': '北京地铁16号线'},
#              '富丰桥站': {'看丹站': '北京地铁16号线', '丰台南路站': '北京地铁16号线'},
#              '丰益桥南站': {'丰台站': '北京地铁16号线', '丽泽商务区站': '北京地铁16号线'},
#              '红莲南路站': {'丽泽商务区站': '北京地铁16号线', '达官营站': '北京地铁16号线'},
#              '玉渊潭站': {'木樨地站': '北京地铁16号线', '甘家口站': '北京地铁16号线'},
#              '甘家口站': {'玉渊潭站': '北京地铁16号线', '二里沟站': '北京地铁16号线'},
#              '万寿寺站': {'国家图书馆站': '北京地铁16号线', '苏州桥站': '北京地铁16号线'},
#              '苏州桥站': {'万寿寺站': '北京地铁16号线', '苏州街站': '北京地铁16号线'},
#              '万泉河桥站': {'苏州街站': '北京地铁16号线', '西苑站': '北京地铁16号线'},
#              '农大南路站': {'西苑站': '北京地铁16号线', '马连洼站': '北京地铁16号线'},
#              '马连洼站': {'农大南路站': '北京地铁16号线', '西北旺站': '北京地铁16号线'},
#              '西北旺站': {'马连洼站': '北京地铁16号线', '永丰南站': '北京地铁16号线'},
#              '永丰南站': {'西北旺站': '北京地铁16号线', '永丰站': '北京地铁16号线'},
#              '永丰站': {'永丰南站': '北京地铁16号线', '屯佃站': '北京地铁16号线'},
#              '屯佃站': {'永丰站': '北京地铁16号线', '稻香湖路站': '北京地铁16号线'},
#              '稻香湖路站': {'屯佃站': '北京地铁16号线', '温阳路站': '北京地铁16号线'},
#              '温阳路站': {'稻香湖路站': '北京地铁16号线', '北安河站': '北京地铁16号线'},
#              '北安河站': {'温阳路站': '北京地铁16号线'}})

# %%
def begin_search(state_start, destation, by_way, is_goal, successors, comparison):
    return Search(state_start, is_goal(destation, by_way), successors, comparison)

# %%
state_start = ('国贸站', '北京地铁1号线', 0, 0)
by_way = ['南礼士路站', '西单站']
begin_search(state_start, '国家图书馆站', by_way, is_goal, successors, comparison)
# Out:
# [('国贸站', '北京地铁1号线', 0, 0),
#  '北京地铁1号线 -> 北京地铁1号线',
#  ('永安里站', '北京地铁1号线', 0, 1),
#  '北京地铁1号线 -> 北京地铁1号线',
#  ('建国门站', '北京地铁1号线', 0, 2),
#  '北京地铁1号线 -> 北京地铁1号线',
#  ('东单站', '北京地铁1号线', 0, 3),
#  '北京地铁1号线 -> 北京地铁1号线',
#  ('王府井站', '北京地铁1号线', 0, 4),
#  '北京地铁1号线 -> 北京地铁1号线',
#  ('天安门东站', '北京地铁1号线', 0, 5),
#  '北京地铁1号线 -> 北京地铁1号线',
#  ('天安门西站', '北京地铁1号线', 0, 6),
#  '北京地铁1号线 -> 北京地铁1号线',
#  ('西单站', '北京地铁1号线', 0, 7),
#  '北京地铁1号线 -> 北京地铁1号线',
#  ('复兴门站', '北京地铁1号线', 0, 8),
#  '北京地铁1号线 -> 北京地铁1号线',
#  ('南礼士路站', '北京地铁1号线', 0, 9),
#  '北京地铁1号线 -> 北京地铁1号线',
#  ('木樨地站', '北京地铁1号线', 0, 10),
#  '北京地铁1号线 -> 北京地铁1号线',
#  ('军事博物馆站', '北京地铁1号线', 0, 11),
#  '北京地铁1号线 -> 北京地铁9号线',
#  ('白堆子站', '北京地铁9号线', 1, 12),
#  '北京地铁9号线 -> 北京地铁9号线',
#  ('白石桥南站', '北京地铁9号线', 1, 13),
#  '北京地铁9号线 -> 北京地铁9号线',
#  ('国家图书馆站', '北京地铁9号线', 1, 14)]

# %% [markdown]
# # Draw a map of beijing subway

# %%
import networkx as nx

# %%
def get_subway_connection(lines):
    dict_successors = collections.defaultdict(list)
    for _, stations in lines.items():
        for a, b in double(stations):
            dict_successors[a].append(b)
            dict_successors[b].append(a)
    return dict_successors

# %%
stations = get_subway_connection(dict_line)

# %%
g = nx.Graph(stations)

# %%
nx.draw(g, node_size=60, font_size=12, with_labels=True)
